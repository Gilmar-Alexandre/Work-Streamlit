# %%
import pandas as pd

# %%
df = pd.read_excel("planilhas/dados_estruturados.xlsx")
df.head()
# Out:
#   CONTRATO Nº      EMPRESA     SISTEMA     INÍCIO    TÉRMINO       MÊS  \
# 0     17/2022  EMPRESA 278  SISTEMA 01 2024-04-01 2025-04-01     ABRIL
# 1     17/2022  EMPRESA 279  SISTEMA 04 2024-04-01 2025-04-01     ABRIL
# 2     18/2019  EMPRESA 278  SISTEMA 03 2024-11-10 2024-11-10  Novembro
# 3     18/2019  EMPRESA 278  SISTEMA 03 2024-11-10 2024-11-10  Novembro
# 4     18/2019  EMPRESA 278  SISTEMA 03 2024-11-10 2024-11-10  Novembro
#
#       VIGÊNCIA ÍNDICE PERÍODO DE FATURAMENTO  VALOR PAGO  ...  \
# 0  DETERMINADO  IGP-M                 MENSAL         879  ...
# 1  DETERMINADO  IGP-M                 MENSAL         356  ...
# 2  Determinado   IPCA                 Mensal         100  ...
# 3  Determinado   IPCA                 Mensal         100  ...
# 4  Determinado   IPCA                 Mensal         100  ...
#
#    ÍNDICE PUBLICADO ÍNDICE APLICADO VALOR REAJUSTADO  \
# 0                 0               0            879.0
# 1                 0               0            356.0
# ...
